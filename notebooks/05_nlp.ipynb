# %% [markdown]
# # 05 - Procesamiento de Lenguaje Natural (NLP)
# Tokenización, vectorización, análisis de sentimiento u otros modelos de texto.

# %%
import pandas as pd
import nltk

PROCESSED_PATH = '../data/processed/'
OUTPUTS_PATH = '../outputs/'
