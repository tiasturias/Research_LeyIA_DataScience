# %% [markdown]
# # 03 - Análisis Exploratorio de Datos (EDA)
#
# > **Nota importante (v2):** El análisis exploratorio completo ha sido migrado y actualizado a **ADE v2**.
# >
# > - **Notebook principal:** `ADE/01_ADE_Analisis_Exploratorio.ipynb` (kernel: `.venv_linux`)
# > - **Outputs generados:** `ADE/outputs/` (14 archivos PNG/CSV)
# > - **Cobertura:** Dataset 86 × 105, corpus legal-IA 38/86 países, comparación IAPP vs propuestas skill
# >
# > Este archivo se mantiene como referencia legacy. Para el análisis actualizado, ejecutar el notebook en `ADE/`.

# %%
# Redirigir al ADE v2
import os
print('Ejecutar: ADE/01_ADE_Analisis_Exploratorio.ipynb')
